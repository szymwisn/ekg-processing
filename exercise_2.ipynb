# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt

# %%
def plot(time, amplitudes, title, xlabel, ylabel):
    fig = plt.figure(figsize=(8,5))
    ax = plt.axes()
    ax.set(xlabel=xlabel, ylabel=ylabel, title=title)
    ax.grid()
    ax.plot(time, amplitudes)
    plt.show()

# %% [markdown]
# ### 1. Wygeneruj ciąg próbek odpowiadający fali sinusoidalnej o częstotliwości 50 Hz i długości 65536.

# %%
f = 50
length = 65536
fs = 1000

time = np.arange(length) / fs
amplitudes = np.sin(f * 2 * np.pi * time)

plot(time, amplitudes, f'Fala sinusoidalna {f} Hz o dlugosci {length}', 'time [s]', 'amplitude')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### 2. Wyznacz dyskretną transformatę Fouriera tego sygnału i przedstaw jego widmo amplitudowe na wykresie w zakresie częstotliwości [0, fs/2], gdzie fs oznacza częstotliwość próbkowania.

# %%
fft = np.fft.fft(amplitudes) / length
fft_abs = np.abs(fft)
frequencies = fs * np.arange(length) / length

half = int(length/2)

plot(frequencies[0:half], fft_abs[0:half], f'Widmo sygnalu', 'frequency [Hz]', 'amplitude')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### 3. Wygeneruj ciąg próbek mieszaniny dwóch fal sinusoidalnych (tzn. ich kombinacji liniowej) o częstotliwościach 50 i 60 Hz. Wykonaj zadanie z punktu 2 dla tego sygnału.

# %%
f1 = 50
f2 = 60

amplitudes1 = np.sin(f1 * 2 * np.pi * time)
amplitudes2 = np.sin(f2 * 2 * np.pi * time)
amplitudes = amplitudes1 + amplitudes2

plot(time, amplitudes, f'Mieszanina dwoch fal sinusoidalnych {f1} Hz i {f2} Hz o dlugosci {length}', 'time [s]', 'amplitude')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
fft = np.fft.fft(amplitudes) / length
fft_abs = np.abs(fft)
frequencies = fs * np.arange(length) / length

half = int(length/2)

plot(frequencies[0:half], fft_abs[0:half], f'Widmo sygnalu', 'frequency [Hz]', 'amplitude')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### 4. Powtórz eksperymenty dla różnych czasów trwania sygnałów, tzn. dla różnych częstotliwości próbkowania.

# %%
f = 25
length = 65536
fs = 500

time = np.arange(length) / fs
amplitudes = np.sin(f * 2 * np.pi * time)

plot(time, amplitudes, f'Fala sinusoidalna {f} Hz o dlugosci {length}', 'time [s]', 'amplitude')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
fft = np.fft.fft(amplitudes) / length
fft_abs = np.abs(fft)
frequencies = fs * np.arange(length) / length

half = int(length/2)

plot(frequencies[0:half], fft_abs[0:half], f'Widmo sygnalu', 'frequency [Hz]', 'amplitude')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ### 5. Wyznacz odwrotne transformaty Fouriera ciągów wyznaczonych w zadaniu 2 i porównaj z ciągami oryginalnymi.

# %%
f = 50
length = 65536
fs = 1000

time = np.arange(length) / fs
amplitudes = np.sin(f * 2 * np.pi * time)

plot(time, amplitudes, f'Fala sinusoidalna {f} Hz o dlugosci {length}', 'time [s]', 'amplitude')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
fft = np.fft.fft(amplitudes) / length
fft_abs = np.abs(fft)
frequencies = fs * np.arange(length) / length

half = int(length/2)

plot(frequencies[0:half], fft_abs[0:half], f'Widmo sygnalu', 'frequency [Hz]', 'amplitude')
# Out:
# <img src="data:image/png;base64,..." width="800">

# %%
reversed_amplitudes = np.fft.ifft(fft).real

plot(time, reversed_amplitudes, f'Odtworzony sygnal', 'time [s]', 'amplitude')
# Out:
# <img src="data:image/png;base64,..." width="800">
